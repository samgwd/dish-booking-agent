# %%
import requests

resp = requests.get(
    "http://127.0.0.1:8000/send-message",
    params={"message": "Hello, world!"},
    timeout=30,
)

resp.raise_for_status()
print(resp.json())
# Out:
# ['Hi there! Nice to meet you.\n\nHow can I help today? I can handle:\n- Checking room availability (Dish MCP) for a date/time and room(s)\n- Booking or canceling a meeting room\n- Viewing or managing Google Calendar events (list, create, update, delete)\n\nIf you want to proceed, tell me:\n- For room booking: date/time, duration, room preference, and any title/attendees\n- For calendar: what event you want to create/update/delete, with date/time, title, and attendees\n\nExamples:\n- “Check availability for Room A tomorrow from 2–4pm.”\n- “Book Room B on 2025-12-07 from 10:00 to 11:00 for a team sync.”\n- “Create a Google Calendar event named ‘Project Kickoff’ for 2025-12-08 09:30–10:30 with Attendees: alice@example.com, bob@example.com.”\n\nWhat would you like to do?']
